# %% [markdown]
# # Assignment 3

# %% [markdown]
# ## Question 1
# ### step1
# * 下载 `Energy+Indicators.xls`，该文件是联合国 2013 年能源供应和可再生电力生产的指标清单
# * 应将其放入变量名为 `energy` 的 DataFrame 中
#   * 注意，这是一个 Excel 文件，而不是 CSV 文件
#   * 请确保将数据文件中的页眉、页脚信息排除在外
#   * 前两列是不需要的，所以应该去掉
#   * 应该改变列标签，使列是 ["Country", "Energy Supply", "Energy Supply per Capita", "% Renewable"]
# * 将 "Energy Supply" 转换为千兆焦耳gigajoules（1,000,000 gigajoules = 1 petajoule）
# * 对所有数据缺失的国家（例如：带有...字样的数据），确保其反映为 np.NaN 值
# * 给下面清单中的国家重命名（供之后的问题使用）：
#
#   "Republic of Korea": "South Korea",
#
#   "United States of America": "United States",
#
#   "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
#
#   "China, Hong Kong Special Administrative Region": "Hong Kong"
# * 还有一些国家的名称中带有数组/括号，请删除这些数字/括号
#
#   * 'Bolivia (Plurinational State of)'应改为'Bolivia'
#
#   * 'Switzerland17'应改为'Switzerland'
#
# ### step2
# * 下载 `world_bank.csv` ，从中获取 GDP 数据，该文件是一个 CSV 文件，包含了从世界银行获取的 1960-2015 年各个国家的 GDP
# * 将其放入变量名为 `GDP` 的 DataFrame 中
# * 务必跳过标题
# * 重命名以下国家
#
#   "Korea, Rep.": "South Korea",
#
#   "Iran, Islamic Rep.": "Iran",
#
#   "Hong Kong SAR, China": "Hong Kong"
#
# ### step3
# * 下载 `scimagojr-3.xlsx`，从中获取能源工程与动力技术的 Scimago 期刊和国家排名数据，该数据根据各国在上述领域的期刊贡献进行排名
# * 将其放入变量名为 `ScimEn` 的 DataFrame 中
# * 将 GDP、Energy、ScimEn组成一个新的数据集，使用国家名称作为交叉点
# * 只使用过去 10 年（2006-2015 年）的 GDP 数据，并且只使用 Scimagojr 排名前 15 名的国家
# * 这个 DataFrame 的索引应该是国家的名称，列应该是
#    ['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']
# ### def answer_one()
#   这个函数应该返回一个有 20 列和 15 个条目的 DataFrame

# %%
import pandas as pd
import numpy as np

# %%
#去掉不需要的信息
energy = pd.read_excel("Energy+Indicators.xls")
energy = energy.iloc[17:244,2:]
energy.reset_index(drop = True, inplace = True)
energy.head(265)
# Out:
#                     Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0                  Afghanistan        321         10    78.6693
# 1                      Albania        102         35        100
# 2                      Algeria       1959         51    0.55101
# 3               American Samoa        ...        ...   0.641026
# 4                      Andorra          9        121    88.6957
# ..                         ...        ...        ...        ...
# 222                   Viet Nam       2554         28    45.3215
# 223  Wallis and Futuna Islands          0         26          0
# 224                      Yemen        344         13          0
# 225                     Zambia        400         26    99.7147
# 226                   Zimbabwe        480         32    52.5361
#
# [227 rows x 4 columns]

# %%
#改变标签
energy.columns = ["Country", "Energy Supply", "Energy Supply per Capita", "% Renewable"]
energy.head()
# Out:
#           Country Energy Supply Energy Supply per Capita % Renewable
# 0     Afghanistan           321                       10     78.6693
# 1         Albania           102                       35         100
# 2         Algeria          1959                       51     0.55101
# 3  American Samoa           ...                      ...    0.641026
# 4         Andorra             9                      121     88.6957

# %%
#转换单位
energy["Energy Supply"] *= 1000000
energy.head()
# Out:
#           Country                                      Energy Supply  \
# 0     Afghanistan                                          321000000
# 1         Albania                                          102000000
# 2         Algeria                                         1959000000
# 3  American Samoa  .................................................
# 4         Andorra                                            9000000
#
#   Energy Supply per Capita % Renewable
# 0                       10     78.6693
# 1                       35         100
# 2                       51     0.55101
# 3                      ...    0.641026
# 4                      121     88.6957

# %%
#缺失值处理
#df.where(cond, other=nan,inplace=False,axis=None,level=None,errors="raise",try_cast=False)
#df.where 将条件为False的部分替换
#cond参数，当cond为True，保持原有值，当cond为False，替换为other值
#other参数，当cond为False时替换为other
energy.where(energy != "...", np.NaN)
# Out:
#                        Country  \
# 0                  Afghanistan
# 1                      Albania
# 2                      Algeria
# 3               American Samoa
# 4                      Andorra
# ..                         ...
# 222                   Viet Nam
# 223  Wallis and Futuna Islands
# 224                      Yemen
# 225                     Zambia
# 226                   Zimbabwe
#
#                                          Energy Supply  \
# 0                                            321000000
# 1                                            102000000
# 2                                           1959000000
# 3    .................................................
# 4                                              9000000
# ..                                                 ...
# 222                                         2554000000
# 223                                                  0
# 224                                          344000000
# 225                                          400000000
# 226                                          480000000
#
#     Energy Supply per Capita % Renewable
# 0                         10     78.6693
# 1                         35         100
# 2                         51     0.55101
# 3                        NaN    0.641026
# 4                        121     88.6957
# ..                       ...         ...
# 222                       28     45.3215
# 223                       26           0
# 224                       13           0
# 225                       26     99.7147
# 226                       32     52.5361
#
# [227 rows x 4 columns]

# %%
#重命名
energy.Country["Republic of Korea"] = "South Korea"
energy.Country["United States of America"] = "United States"
energy.Country["United Kingdom of Great Britain and Northern Ireland"] = "United Kingdom"
energy.Country["China, Hong Kong Special Administrative Region"] = "Hong Kong"
energy.head()
# Out:
#           Country                                      Energy Supply  \
# 0     Afghanistan                                          321000000
# 1         Albania                                          102000000
# 2         Algeria                                         1959000000
# 3  American Samoa  .................................................
# 4         Andorra                                            9000000
#
#   Energy Supply per Capita % Renewable
# 0                       10     78.6693
# 1                       35         100
# 2                       51     0.55101
# 3                      ...    0.641026
# 4                      121     88.6957

# %%
#删除数字、括号
energy.Country["Bolivia (Plurinational State of)"] = "Bolivia"
energy.Country['Switzerland17'] = "Switzerland"

# %%
GDP = pd.read_csv("world_bank.csv", header = 4)
GDP = GDP[3:].reset_index()
GDP.head()
# Out:
#    index          Country Name Country Code  \
# 0      3                Angola          AGO
# 1      4               Albania          ALB
# 2      5            Arab World          ARB
# 3      6  United Arab Emirates          ARE
# 4      7             Argentina          ARG
#
#                              Indicator Name  Indicator Code          1960  \
# 0  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD           NaN
# 1  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD           NaN
# 2  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD           NaN
# 3  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD           NaN
# 4  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD  1.206739e+11
#
#            1961          1962          1963          1964  ...          2006  \
# 0           NaN           NaN           NaN           NaN  ...  5.581103e+10
# 1           NaN           NaN           NaN           NaN  ...  9.771760e+09
# 2           NaN           NaN           NaN           NaN  ...  1.763824e+12
# 3           NaN           NaN           NaN           NaN  ...  2.789489e+11
# 4  1.272239e+11  1.261399e+11  1.194442e+11  1.315442e+11  ...  3.788140e+11
#
#            2007          2008          2009          2010          2011  \
# 0  6.842044e+10  7.787420e+10  7.975320e+10  8.247091e+10  8.570262e+10
# 1  1.034829e+10  1.112752e+10  1.150029e+10  1.192695e+10  1.223109e+10
# 2  1.863481e+12  1.980983e+12  2.011001e+12  2.103825e+12  2.173896e+12
# 3  2.878318e+11  2.970189e+11  2.814464e+11  2.860493e+11  3.009462e+11
# 4  4.089887e+11  4.215649e+11  4.217758e+11  4.616402e+11  5.003555e+11
#
#            2012          2013          2014          2015
# 0  9.012096e+10  9.626143e+10  1.008863e+11  1.039106e+11
# 1  1.240477e+10  1.254247e+10  1.279331e+10  1.312082e+10
# 2  2.318267e+12  2.385580e+12  2.436659e+12  2.509068e+12
# 3  3.216922e+11  3.355937e+11  3.509313e+11  3.621003e+11
# 4  5.043671e+11  5.189199e+11  5.212737e+11           NaN
#
# [5 rows x 61 columns]

# %%
#重命名
GDP["Country Name"]["Korea, Rep."] = "South Korea"
GDP["Country Name"]["Iran, Islamic Rep."] = "Iran"
GDP["Country Name"]["Hong Kong SAR, China"] = "Hong Kong"
GDP.head()
# Out:
# <ipython-input-10-407c600fcd35>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GDP["Country Name"]["Korea, Rep."] = "South Korea"
#    index          Country Name Country Code  \
# 0      3                Angola          AGO
# 1      4               Albania          ALB
# 2      5            Arab World          ARB
# 3      6  United Arab Emirates          ARE
# 4      7             Argentina          ARG
#
#                              Indicator Name  Indicator Code          1960  \
# 0  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD           NaN
# 1  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD           NaN
# 2  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD           NaN
# 3  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD           NaN
# 4  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD  1.206739e+11
#
#            1961          1962          1963          1964  ...          2006  \
# 0           NaN           NaN           NaN           NaN  ...  5.581103e+10
# 1           NaN           NaN           NaN           NaN  ...  9.771760e+09
# 2           NaN           NaN           NaN           NaN  ...  1.763824e+12
# 3           NaN           NaN           NaN           NaN  ...  2.789489e+11
# 4  1.272239e+11  1.261399e+11  1.194442e+11  1.315442e+11  ...  3.788140e+11
#
#            2007          2008          2009          2010          2011  \
# 0  6.842044e+10  7.787420e+10  7.975320e+10  8.247091e+10  8.570262e+10
# 1  1.034829e+10  1.112752e+10  1.150029e+10  1.192695e+10  1.223109e+10
# 2  1.863481e+12  1.980983e+12  2.011001e+12  2.103825e+12  2.173896e+12
# 3  2.878318e+11  2.970189e+11  2.814464e+11  2.860493e+11  3.009462e+11
# 4  4.089887e+11  4.215649e+11  4.217758e+11  4.616402e+11  5.003555e+11
#
#            2012          2013          2014          2015
# 0  9.012096e+10  9.626143e+10  1.008863e+11  1.039106e+11
# 1  1.240477e+10  1.254247e+10  1.279331e+10  1.312082e+10
# 2  2.318267e+12  2.385580e+12  2.436659e+12  2.509068e+12
# 3  3.216922e+11  3.355937e+11  3.509313e+11  3.621003e+11
# 4  5.043671e+11  5.189199e+11  5.212737e+11           NaN
#
# [5 rows x 61 columns]

# %%
ScimEn = pd.read_excel("scimagojr-3.xlsx")
ScimEn.head()
# Out:
#    Rank             Country  Documents  Citable documents  Citations  \
# 0     1               China     127050             126767     597237
# 1     2       United States      96661              94747     792274
# 2     3               Japan      30504              30287     223024
# 3     4      United Kingdom      20944              20357     206091
# 4     5  Russian Federation      18534              18301      34266
#
#    Self-citations  Citations per document  H index
# 0          411683                    4.70      138
# 1          265436                    8.20      230
# 2           61554                    7.31      134
# 3           37874                    9.84      139
# 4           12422                    1.85       57

# %%
energy.head()
# Out:
#           Country                                      Energy Supply  \
# 0     Afghanistan                                          321000000
# 1         Albania                                          102000000
# 2         Algeria                                         1959000000
# 3  American Samoa  .................................................
# 4         Andorra                                            9000000
#
#   Energy Supply per Capita % Renewable
# 0                       10     78.6693
# 1                       35         100
# 2                       51     0.55101
# 3                      ...    0.641026
# 4                      121     88.6957
